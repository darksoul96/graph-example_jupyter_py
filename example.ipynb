# %%
import pandas

# %%
from matplotlib import pyplot

# %%
x = [1,2,3]
y = [1,4,9]
z = [10,5,0]
pyplot.plot(x,y)
pyplot.plot(x,z)
pyplot.title("test plot")
pyplot.xlabel("X")
pyplot.ylabel("Y and Z")
pyplot.legend(["line 1", "line 2"])
pyplot.show()
